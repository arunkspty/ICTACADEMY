# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('iris.csv')

# %%
data.mean(axis =0)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_8800/49858174.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis =0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.mean(axis=None, skipna=None, level=None, numeric_only=None)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_8800/4157519230.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis=None, skipna=None, level=None, numeric_only=None)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
plt.figure()
plt.hist(data['SL'],color='yellow',rwidth=0.9,density=True)
plt.title('Distribution Vs Frequency of SL')
plt.xlabel('Distribution')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure()
plt.hist(data['SL'],color='yellow',rwidth=0.9,density=True,cumulative=True)
plt.title('Distribution Vs Cumulative Frequency of SL')
plt.xlabel('Distribution')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(data['PL'],color='yellow',rwidth=0.9,density=True)
plt.title('Distribution Vs Frequency of PL')
plt.xlabel('Distribution')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data[['SL','PL']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data[['SL','PL']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure()
plt.scatter(data['SL'],data['PL'],s=10)
plt.title('Plot of SL Vs PL')
plt.xlabel('SL')
plt.ylabel('PL')
# Out:
# Text(0, 0.5, 'PL')

# %%
plt.figure()
plt.scatter(data['SW'],data['PW'],s=10,c='red')
plt.title('Plot of SW Vs PW')
plt.xlabel('SW')
plt.ylabel('PW')
# Out:
# Text(0, 0.5, 'PW')

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,1,1)
plt.scatter(data['SL'],data['PL'],s=10)
plt.title('Plot of SL Vs PL')
plt.xlabel('SL')
plt.ylabel('PL')

plt.subplot(2,1,2)
plt.scatter(data['SW'],data['PW'],s=10,c='red')
plt.title('Plot of SW Vs PW')
plt.xlabel('SW')
plt.ylabel('PW')

plt.tight_layout()

# %%
sns.pairplot(data)

# %%
slice_plot=data[['SL','PL']]
sns.pairplot(slice_plot)

# %%
sns.heatmap(slice_plot.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(data['SL'])
plt.title('SL')
# Out:
# Text(0.5, 1.0, 'SL')

# %%
plt.boxplot(data['PL'])
plt.title('PL')
# Out:
# Text(0.5, 1.0, 'PL')

# %%
sns.boxplot(x='SL',y='PL',data=data)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='PL'>

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,1,1)
sns.stripplot(data['SL'])

plt.subplot(2,1,2)
sns.stripplot(data['PL'])
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PL'>

# %%
sns.stripplot(x='SL',y='PL',data=data)
sns.swarmplot(x='SL',y='PL',data=data)
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='SL', ylabel='PL'>

# %%
sns.violinplot(x='SL',data=data)
# Out:
# <AxesSubplot:xlabel='SL'>

# %%
sns.countplot(data['SL'])
plt.grid()
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
