# %% [markdown]
# # Group 8_Week6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Dataset_w6.csv")
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   country                                     196 non-null    object
#  1   Region                                      196 non-null    object
#  2   Surface area (km2)                          196 non-null    int64
#  3   Population in thousands (2017)              196 non-null    int64
#  4   GDP per capita (current US$)                196 non-null    float64
#  5   Agricultural production index               196 non-null    int64
#  6   International trade: Imports (million US$)  196 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 10.8+ KB

# %% [markdown]
# # 1. Find out how many countries are there in the dataset.

# %%
print('There are',data['country'].nunique(),'countries in the dataset')
# Out:
# There are 196 countries in the dataset

# %% [markdown]
# # 2. Examine the data by using visualizations

# %%
data.describe()
# Out:
#        Surface area (km2)  Population in thousands (2017)  \
# count        1.960000e+02                    1.960000e+02
# mean         6.787071e+05                    3.796658e+04
# std          1.914200e+06                    1.434228e+05
# min          2.600000e+01                    5.000000e+00
# 25%          2.084900e+04                    1.462000e+03
# 50%          1.136275e+05                    7.677500e+03
# 75%          5.077380e+05                    2.624075e+04
# max          1.709825e+07                    1.409517e+06
#
#        GDP per capita (current US$)  Agricultural production index   \
# count                    196.000000                      196.000000
# mean                   13727.343367                      117.066327
# std                    18995.593914                       25.521247
# min                      144.500000                       34.000000
# 25%                     1840.725000                      102.000000
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(8,6))
sns.stripplot(data['GDP per capita (current US$)'])
plt.title('Distribution of GDP per capita (current US$) among the 196 countries')
plt.xlabel('GDP per capita (current US$)')
print('50% of the contries have a GD of <= $5463.450. Clearly 2 outliers can be identifis in this dataset which have the highest GDP  among the 196 countries')
# Out:
# 50% of the contries have a GD of <= $5463.450. Clearly 2 outliers can be identifis in this dataset which have the highest GDP  among the 196 countries

# %%
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(8,6))
sns.stripplot(data['Population in thousands (2017)'])
plt.title('Distribution of Population (in thousands (2017)) among the 196 countries')
plt.xlabel('Population in thousands (2017)')
print('Like the GDP distribution, the distribution of population is aslo concentrated with 2 clearly visible outliers')
# Out:
# Like the GDP distribution, the distribution of population is aslo concentrated with 2 clearly visible outliers

# %% [markdown]
# # 3. Find out how many countries with respect to the region are available in the dataset

# %%
region=data.groupby("Region")['country'].nunique()
region
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %%
pd.DataFrame.count(df2)
# Out:
# count    22
# mean     22
# std      22
# min      22
# 25%      22
# 50%      22
# 75%      22
# max      22
# dtype: int64

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x= 'Region',data = data)
plt.xticks(rotation=90)
plt.title("Number of Countries in each Region",fontsize=16,fontweight='bold')
plt.ylabel("Number of countries",fontsize=12,fontweight='bold')
plt.xlabel("Regions",fontsize=12,fontweight='bold')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.25))
plt.show()

print("There are 22 regions out of which West Asia Region has the highest number of countries and Oceania Region has the lowest.")
# Out:
# There are 22 regions out of which West Asia Region has the highest number of countries and Oceania Region has the lowest.

# %% [markdown]
# # 4. On average which region has the highest
# a. GDP per capita (current US$)
# b. International trade: Imports (million US$)

# %%
df1=data.groupby('Region')['GDP per capita (current US$)']
df2=df1.describe()
df2['mean'].mean().round(2)
# Out:
# 16109.07

# %%
df2
# Out:
#                    count          mean           std      min        25%  \
# Region
# Caribbean           16.0  15135.562500  14579.371326    793.7   6973.125
# CentralAmerica       8.0   6348.137500   4180.440883   2086.9   3558.100
# CentralAsia          5.0   4329.880000   4152.215490    925.9   1106.400
# EasternAfrica       17.0   2088.852941   3716.131770    144.5    529.200
# EasternAsia          7.0  27967.614286  27485.120923    648.0   6041.250
# EasternEurope       10.0   9292.490000   5415.488739   1591.4   6024.800
# Melanesia            5.0   9261.960000  13855.842686   1841.6   2783.000
# Micronesia           4.0   5008.300000   4820.669694   1442.9   2622.125
# MiddleAfrica         9.0   3928.833333   5274.846281    333.2    713.000
# NorthernAfrica       5.0   3934.960000    974.706575   2919.3   3452.300
# NorthernAmerica      4.0  57659.000000  25749.619445  36976.7  41648.375
# NorthernEurope      10.0  42098.220000  20671.030185  13704.1  23371.025
# ...

# %%
plt.figure(figsize=(8,6))
data.groupby('Region')['GDP per capita (current US$)'].mean().plot.bar(color='green')
plt.title("Average Regional GDP")
plt.ylabel("Average GDP")
plt.show()
print('On the basis of the average GDP w.r.t the regions, $16109.07 is the average GDP of all the 22 regions. North America has the   highest average GDP.')
# Out:
# On the basis of the average GDP w.r.t the regions, $16109.07 is the average GDP of all the 22 regions. North America has the   highest average GDP.

# %%
df3=data.groupby('Region')['International trade: Imports (million US$)']
df4=df3.describe()
df4['mean'].mean().round(2)
# Out:
# 104060.84

# %%
df4
# Out:
#                    count           mean           std      min        25%  \
# Region
# Caribbean           16.0    3057.312500  5.545571e+03     36.0     346.25
# CentralAmerica       8.0   57031.500000  1.334501e+05    952.0    7817.75
# CentralAsia          5.0   12063.400000  1.219609e+04   2616.0    3030.00
# EasternAfrica       17.0    4726.176471  5.132033e+03    193.0     987.00
# EasternAsia          7.0  451995.000000  5.666631e+05   2757.0    6141.00
# EasternEurope       10.0   85243.900000  6.549471e+04   4020.0   31452.25
# Melanesia            5.0    2896.400000  3.478912e+03    416.0     454.00
# Micronesia           4.0      99.000000  4.818022e+01     40.0      74.50
# MiddleAfrica         9.0    4381.222222  3.527843e+03    139.0    1371.00
# NorthernAfrica       5.0   35034.400000  2.028881e+04   8876.0   19456.00
# NorthernAmerica      4.0  663552.250000  1.074266e+06    623.0     884.00
# NorthernEurope      10.0  113407.200000  1.881145e+05   5703.0   18694.50
# ...

# %%
plt.figure(figsize=(8,6))
data.groupby('Region')['International trade: Imports (million US$)'].mean().plot.bar(color='red')
plt.title("Average Regionl International Import Trade")
plt.ylabel("Average International Import trade")
plt.show()
print('On the basis of the average international imports trade w.r.t the regions, $104060.84 is the average imports trade of all the  22 regions. North America has the highest international import trade.')
# Out:
# On the basis of the average international imports trade w.r.t the regions, $104060.84 is the average imports trade of all the  22 regions. North America has the highest international import trade.

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
df6=data[['Region','country','GDP per capita (current US$)']]
df6
# Out:
#                 Region                             country  \
# 0         SouthernAsia                         Afghanistan
# 1       SouthernEurope                             Albania
# 2       NorthernAfrica                             Algeria
# 3         MiddleAfrica                              Angola
# 4            Caribbean                 Antigua and Barbuda
# ..                 ...                                 ...
# 191       SouthAmerica  Venezuela (Bolivarian Republic of)
# 192  South-easternAsia                            Viet Nam
# 193        WesternAsia                               Yemen
# 194      EasternAfrica                              Zambia
# 195      EasternAfrica                            Zimbabwe
#
#      GDP per capita (current US$)
# 0                           623.2
# 1                          3984.2
# 2                          4154.1
# 3                          4714.1
# 4                         14764.5
# ..                            ...
# ...

# %%
df7=df6[(data['Region']=='Caribbean')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Aqua',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Caribbean region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='CentralAmerica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Aquamarine',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Central America region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='CentralAsia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Bisque',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Central Asia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='EasternAfrica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Blue',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Eastern Africa region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='EasternAsia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='BlueViolet',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Eastern Asia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='EasternEurope')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Brown',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Eastern Europe region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='Melanesia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='BurlyWood',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Melanesia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='Micronesia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='CadetBlue',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Micronesia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='MiddleAfrica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Chartreuse',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Middle Africa region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='NorthernAfrica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Chocolate',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Northern Africa region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='NorthernAmerica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Coral',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the  Northern America region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='NorthernEurope')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='CornflowerBlue',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Northern Europe region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)') Oceania
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='Oceania')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Crimson',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Oceania region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='Polynesia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='Cyan',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Polynesia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='South-easternAsia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkBlue',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the South-easternAsia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='SouthAmerica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkCyan',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the South America region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='SouthernAfrica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkGoldenRod',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Southern Africa region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='SouthernAsia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkGray',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Southern Asia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='SouthernEurope')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkMagenta',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Southern Europe region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='WesternAfrica')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkOliveGreen',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Western Africa region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='WesternAsia')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='DarkSalmon',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Western Asia region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %%
df7=df6[(data['Region']=='WesternEurope')]
plt.bar(df7['country'], df7['GDP per capita (current US$)'], color ='GreenYellow',
        width = 0.4)
plt.xticks(rotation=90)
plt.title("GDP of Countries in the Western Europe region",fontsize=12,fontweight='bold')
plt.ylabel('GDP per capita (US$)')
# Out:
# Text(0, 0.5, 'GDP per capita (US$)')

# %% [markdown]
# Northern African and Western European Region showed a steady GDP per capita distribution among its member nations
